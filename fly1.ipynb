# %%
import pandas as pd
import numpy as np

# %%
num_nodes = 100
data = {
    "node_id": np.arange(1, num_nodes + 1),
    "node_state": np.random.choice(["active", "inactive", "sleep"], num_nodes),
    "traffic_load": np.random.uniform(0, 100, num_nodes),
    "energy_level": np.random.uniform(0, 100, num_nodes),
    "transmission_delay": np.random.uniform(0, 10, num_nodes)
}

# %%
df = pd.DataFrame(data)
df.to_csv("network_data.csv", index=False)
print(df.head())
# Out:
#    node_id node_state  traffic_load  energy_level  transmission_delay
# 0        1   inactive     47.810253     69.176033            9.953309
# 1        2     active      9.600792     55.176905            6.434597
# 2        3     active     39.832926     65.794440            2.820273
# 3        4      sleep     49.736471     23.170015            6.385423
# 4        5     active     87.628359     37.748804            8.488437
